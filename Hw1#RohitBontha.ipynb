# %%
pwd
# Out:
# 'C:\\Users\\Rohit'

# %%
cd SJSU\SJSU 2nd sem\machine learning\assignment 2\Data set
# Out:
# C:\Users\Rohit\SJSU\SJSU 2nd sem\machine learning\assignment 2\Data set

# %%
import pandas as d
data = d.read_excel(r"C:\Users\Rohit\Desktop\SJSU\SJSU 2nd Sem\Machine Learning\Assignment 2\Data Set\servo.xlsx")
data.head()
# Out:
#   Motor Screw  pgain  vgain     class
# 0     E     E      5      4  0.281251
# 1     B     D      6      5  0.506252
# 2     D     D      4      3  0.356251
# 3     B     A      3      2  5.500033
# 4     D     B      6      5  0.356251

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
# Motor    167 non-null object
# Screw    167 non-null object
# pgain    167 non-null int64
# vgain    167 non-null int64
# class    167 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.6+ KB

# %%
# %pwd
# Out:
# 'C:\\Users\\Rohit\\SJSU\\SJSU 2nd sem\\machine learning\\assignment 2\\Data set'

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E21B-45DC
#
#  Directory of C:\Users\Rohit\SJSU\SJSU 2nd sem\machine learning\assignment 2\Data set
#
# 07-02-2020  01:01    <DIR>          .
# 07-02-2020  01:01    <DIR>          ..
# 07-02-2020  00:53               108 Index.csv
# 07-02-2020  00:59             3,186 servo (2).csv
# 07-02-2020  00:42             2,136 servonames.csv
#                3 File(s)          5,430 bytes
#                2 Dir(s)  403,778,801,664 bytes free

# %%
data.describe()
# Out:
#             pgain       vgain       class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922    1.389708
# std      1.017770    1.369850    1.559635
# min      3.000000    1.000000    0.131250
# 25%      3.000000    1.000000    0.503126
# 50%      4.000000    2.000000    0.731254
# 75%      5.000000    4.000000    1.259369
# max      6.000000    5.000000    7.100108

# %%
# %matplotlib inline  
import matplotlib.pyplot as plot
data.hist(bins = 10, figsize = (20,15))
plot.show()

# %%
# %matplotlib inline  
import matplotlib.pyplot as plot
data.hist(bins = 30, figsize = (40,20))
plot.show()

# %%
data.boxplot(column=['pgain','vgain','class'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plot
data.plot(kind = "scatter", x="vgain", y = "class")
plot.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import matplotlib.pyplot as plot
data.plot(kind = "scatter", x="pgain", y = "class")
plot.legend()
# Out:
# No handles with labels found to put in legend.

# %%
corr_matrix = data.corr()
corr_matrix ["pgain"].sort_values(ascending = False)
# Out:
# pgain    1.000000
# vgain    0.812268
# class   -0.598129
# Name: pgain, dtype: float64

# %%
corr_matrix = data.corr()
corr_matrix ["vgain"].sort_values(ascending = False)
# Out:
# vgain    1.000000
# pgain    0.812268
# class   -0.364383
# Name: vgain, dtype: float64

# %%
corr_matrix = data.corr()
corr_matrix ["class"].sort_values(ascending = False)
# Out:
# class    1.000000
# vgain   -0.364383
# pgain   -0.598129
# Name: class, dtype: float64

# %%
Data["Motor"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a9cd764971ae> in <module>
# ----> 1 Data["Motor"]
#
# NameError: name 'Data' is not defined
